# %% [markdown]
# # Question 1
# Write a python Function for finding is a given number prime or not and do Unit Testing on it using
# PyLint and Unittest Library

# %%
def isPrime(n):
    
    '''
    Hey I am testing pyLint of this code
    '''

    if (n <= 1):
        # not a prime number
        print("Not a Prime Number")
    if (n <= 3):
        # is a prime number
        print("Is a Prime Number")
  
    # This is checked so that we can skip 
    # middle five numbers in below loop
    if (n % 2 == 0 or n % 3 == 0):
        print("Not a Prime Number")
  
    i = 5
    while(i * i <= n):
        # not a prime number
        if (n % i == 0 or n % (i + 2) == 0):
            print("Not a Prime Number")
        i = i + 6
  
    print("Prime Number")
    
isPrime(23)
# Out:
# Prime Number

# %% [markdown]
# # Question 2
# Make a small generator program for returning armstrong numbers in between 1-1000 in a
# generator object

# %%
def is_arm(number):
    num_str = str(number)
    num_len = len(num_str)
 
    sum_of_digits = 0
    for d in num_str:
        sum_of_digits += int(d) ** num_len # power operation
 
    if number == sum_of_digits:
        yield True
    else:
        yield False
 
limit = int(input("Please enter the limit for Armstrong number check: "))
 
for n in range(1,limit+1): # 1 to limit (inclusive)
    if is_arm(n):
        print("{} is an Armstrong number of order {}".format(n,len(str(n))))
# Out:
# Please enter the limit for Armstrong number check: 1000
# 1 is an Armstrong number of order 1
# 2 is an Armstrong number of order 1
# 3 is an Armstrong number of order 1
# 4 is an Armstrong number of order 1
# 5 is an Armstrong number of order 1
# 6 is an Armstrong number of order 1
# 7 is an Armstrong number of order 1
# 8 is an Armstrong number of order 1
# 9 is an Armstrong number of order 1
# 10 is an Armstrong number of order 2
# 11 is an Armstrong number of order 2
# 12 is an Armstrong number of order 2
# 13 is an Armstrong number of order 2
# 14 is an Armstrong number of order 2
# 15 is an Armstrong number of order 2
# 16 is an Armstrong number of order 2
# 17 is an Armstrong number of order 2
# 18 is an Armstrong number of order 2
# 19 is an Armstrong number of order 2
# 20 is an Armstrong number of order 2
# 21 is an Armstrong number of order 2
# 22 is an Armstrong number of order 2
# 23 is an Armstrong number of order 2
# 24 is an Armstrong number of order 2
# 25 is an Armstrong number of order 2
# 26 is an Armstrong number of order 2
# 27 is an Armstrong number of order 2
# 28 is an Armstrong number of order 2
# 29 is an Armstrong number of order 2
# 30 is an Armstrong number of order 2
# 31 is an Armstrong number of order 2
# 32 is an Armstrong number of order 2
# 33 is an Armstrong number of order 2
# 34 is an Armstrong number of order 2
# 35 is an Armstrong number of order 2
# 36 is an Armstrong number of order 2
# 37 is an Armstrong number of order 2
# 38 is an Armstrong number of order 2
# 39 is an Armstrong number of order 2
# 40 is an Armstrong number of order 2
# 41 is an Armstrong number of order 2
# 42 is an Armstrong number of order 2
# 43 is an Armstrong number of order 2
# 44 is an Armstrong number of order 2
# 45 is an Armstrong number of order 2
# 46 is an Armstrong number of order 2
# 47 is an Armstrong number of order 2
# 48 is an Armstrong number of order 2
# 49 is an Armstrong number of order 2
# 50 is an Armstrong number of order 2
# 51 is an Armstrong number of order 2
# 52 is an Armstrong number of order 2
# 53 is an Armstrong number of order 2
# 54 is an Armstrong number of order 2
# 55 is an Armstrong number of order 2
# 56 is an Armstrong number of order 2
# 57 is an Armstrong number of order 2
# 58 is an Armstrong number of order 2
# 59 is an Armstrong number of order 2
# 60 is an Armstrong number of order 2
# 61 is an Armstrong number of order 2
# 62 is an Armstrong number of order 2
# 63 is an Armstrong number of order 2
# 64 is an Armstrong number of order 2
# 65 is an Armstrong number of order 2
# 66 is an Armstrong number of order 2
# 67 is an Armstrong number of order 2
# 68 is an Armstrong number of order 2
# 69 is an Armstrong number of order 2
# 70 is an Armstrong number of order 2
# 71 is an Armstrong number of order 2
# 72 is an Armstrong number of order 2
# 73 is an Armstrong number of order 2
# 74 is an Armstrong number of order 2
# 75 is an Armstrong number of order 2
# 76 is an Armstrong number of order 2
# 77 is an Armstrong number of order 2
# 78 is an Armstrong number of order 2
# 79 is an Armstrong number of order 2
# 80 is an Armstrong number of order 2
# 81 is an Armstrong number of order 2
# 82 is an Armstrong number of order 2
# 83 is an Armstrong number of order 2
# 84 is an Armstrong number of order 2
# 85 is an Armstrong number of order 2
# 86 is an Armstrong number of order 2
# 87 is an Armstrong number of order 2
# 88 is an Armstrong number of order 2
# 89 is an Armstrong number of order 2
# 90 is an Armstrong number of order 2
# 91 is an Armstrong number of order 2
# 92 is an Armstrong number of order 2
# 93 is an Armstrong number of order 2
# 94 is an Armstrong number of order 2
# 95 is an Armstrong number of order 2
# 96 is an Armstrong number of order 2
# 97 is an Armstrong number of order 2
# 98 is an Armstrong number of order 2
# 99 is an Armstrong number of order 2
# 100 is an Armstrong number of order 3
# 101 is an Armstrong number of order 3
# 102 is an Armstrong number of order 3
# 103 is an Armstrong number of order 3
# 104 is an Armstrong number of order 3
# 105 is an Armstrong number of order 3
# 106 is an Armstrong number of order 3
# 107 is an Armstrong number of order 3
# 108 is an Armstrong number of order 3
# 109 is an Armstrong number of order 3
# 110 is an Armstrong number of order 3
# 111 is an Armstrong number of order 3
# 112 is an Armstrong number of order 3
# 113 is an Armstrong number of order 3
# 114 is an Armstrong number of order 3
# 115 is an Armstrong number of order 3
# 116 is an Armstrong number of order 3
# 117 is an Armstrong number of order 3
# 118 is an Armstrong number of order 3
# 119 is an Armstrong number of order 3
# 120 is an Armstrong number of order 3
# 121 is an Armstrong number of order 3
# 122 is an Armstrong number of order 3
# 123 is an Armstrong number of order 3
# 124 is an Armstrong number of order 3
# 125 is an Armstrong number of order 3
# 126 is an Armstrong number of order 3
# 127 is an Armstrong number of order 3
# 128 is an Armstrong number of order 3
# 129 is an Armstrong number of order 3
# 130 is an Armstrong number of order 3
# 131 is an Armstrong number of order 3
# 132 is an Armstrong number of order 3
# 133 is an Armstrong number of order 3
# 134 is an Armstrong number of order 3
# 135 is an Armstrong number of order 3
# 136 is an Armstrong number of order 3
# 137 is an Armstrong number of order 3
# 138 is an Armstrong number of order 3
# 139 is an Armstrong number of order 3
# 140 is an Armstrong number of order 3
# 141 is an Armstrong number of order 3
# 142 is an Armstrong number of order 3
# 143 is an Armstrong number of order 3
# 144 is an Armstrong number of order 3
# 145 is an Armstrong number of order 3
# 146 is an Armstrong number of order 3
# 147 is an Armstrong number of order 3
# 148 is an Armstrong number of order 3
# 149 is an Armstrong number of order 3
# 150 is an Armstrong number of order 3
# 151 is an Armstrong number of order 3
# 152 is an Armstrong number of order 3
# 153 is an Armstrong number of order 3
# 154 is an Armstrong number of order 3
# 155 is an Armstrong number of order 3
# 156 is an Armstrong number of order 3
# 157 is an Armstrong number of order 3
# 158 is an Armstrong number of order 3
# 159 is an Armstrong number of order 3
# 160 is an Armstrong number of order 3
# 161 is an Armstrong number of order 3
# 162 is an Armstrong number of order 3
# 163 is an Armstrong number of order 3
# 164 is an Armstrong number of order 3
# 165 is an Armstrong number of order 3
# 166 is an Armstrong number of order 3
# 167 is an Armstrong number of order 3
# 168 is an Armstrong number of order 3
# 169 is an Armstrong number of order 3
# 170 is an Armstrong number of order 3
# 171 is an Armstrong number of order 3
# 172 is an Armstrong number of order 3
# 173 is an Armstrong number of order 3
# 174 is an Armstrong number of order 3
# 175 is an Armstrong number of order 3
# 176 is an Armstrong number of order 3
# 177 is an Armstrong number of order 3
# 178 is an Armstrong number of order 3
# 179 is an Armstrong number of order 3
# 180 is an Armstrong number of order 3
# 181 is an Armstrong number of order 3
# 182 is an Armstrong number of order 3
# 183 is an Armstrong number of order 3
# 184 is an Armstrong number of order 3
# 185 is an Armstrong number of order 3
# 186 is an Armstrong number of order 3
# 187 is an Armstrong number of order 3
# 188 is an Armstrong number of order 3
# 189 is an Armstrong number of order 3
# 190 is an Armstrong number of order 3
# 191 is an Armstrong number of order 3
# 192 is an Armstrong number of order 3
# 193 is an Armstrong number of order 3
# 194 is an Armstrong number of order 3
# 195 is an Armstrong number of order 3
# 196 is an Armstrong number of order 3
# 197 is an Armstrong number of order 3
# 198 is an Armstrong number of order 3
# 199 is an Armstrong number of order 3
# 200 is an Armstrong number of order 3
# 201 is an Armstrong number of order 3
# 202 is an Armstrong number of order 3
# 203 is an Armstrong number of order 3
# 204 is an Armstrong number of order 3
# 205 is an Armstrong number of order 3
# 206 is an Armstrong number of order 3
# 207 is an Armstrong number of order 3
# 208 is an Armstrong number of order 3
# 209 is an Armstrong number of order 3
# 210 is an Armstrong number of order 3
# 211 is an Armstrong number of order 3
# 212 is an Armstrong number of order 3
# 213 is an Armstrong number of order 3
# 214 is an Armstrong number of order 3
# 215 is an Armstrong number of order 3
# 216 is an Armstrong number of order 3
# 217 is an Armstrong number of order 3
# 218 is an Armstrong number of order 3
# 219 is an Armstrong number of order 3
# 220 is an Armstrong number of order 3
# 221 is an Armstrong number of order 3
# 222 is an Armstrong number of order 3
# 223 is an Armstrong number of order 3
# 224 is an Armstrong number of order 3
# 225 is an Armstrong number of order 3
# 226 is an Armstrong number of order 3
# 227 is an Armstrong number of order 3
# 228 is an Armstrong number of order 3
# 229 is an Armstrong number of order 3
# 230 is an Armstrong number of order 3
# 231 is an Armstrong number of order 3
# 232 is an Armstrong number of order 3
# 233 is an Armstrong number of order 3
# 234 is an Armstrong number of order 3
# 235 is an Armstrong number of order 3
# 236 is an Armstrong number of order 3
# 237 is an Armstrong number of order 3
# 238 is an Armstrong number of order 3
# 239 is an Armstrong number of order 3
# 240 is an Armstrong number of order 3
# 241 is an Armstrong number of order 3
# 242 is an Armstrong number of order 3
# 243 is an Armstrong number of order 3
# 244 is an Armstrong number of order 3
# 245 is an Armstrong number of order 3
# 246 is an Armstrong number of order 3
# 247 is an Armstrong number of order 3
# 248 is an Armstrong number of order 3
# 249 is an Armstrong number of order 3
# 250 is an Armstrong number of order 3
# 251 is an Armstrong number of order 3
# 252 is an Armstrong number of order 3
# 253 is an Armstrong number of order 3
# 254 is an Armstrong number of order 3
# 255 is an Armstrong number of order 3
# 256 is an Armstrong number of order 3
# 257 is an Armstrong number of order 3
# 258 is an Armstrong number of order 3
# 259 is an Armstrong number of order 3
# 260 is an Armstrong number of order 3
# 261 is an Armstrong number of order 3
# 262 is an Armstrong number of order 3
# 263 is an Armstrong number of order 3
# 264 is an Armstrong number of order 3
# 265 is an Armstrong number of order 3
# 266 is an Armstrong number of order 3
# 267 is an Armstrong number of order 3
# 268 is an Armstrong number of order 3
# 269 is an Armstrong number of order 3
# 270 is an Armstrong number of order 3
# 271 is an Armstrong number of order 3
# 272 is an Armstrong number of order 3
# 273 is an Armstrong number of order 3
# 274 is an Armstrong number of order 3
# 275 is an Armstrong number of order 3
# 276 is an Armstrong number of order 3
# 277 is an Armstrong number of order 3
# 278 is an Armstrong number of order 3
# 279 is an Armstrong number of order 3
# 280 is an Armstrong number of order 3
# 281 is an Armstrong number of order 3
# 282 is an Armstrong number of order 3
# 283 is an Armstrong number of order 3
# 284 is an Armstrong number of order 3
# 285 is an Armstrong number of order 3
# 286 is an Armstrong number of order 3
# 287 is an Armstrong number of order 3
# 288 is an Armstrong number of order 3
# 289 is an Armstrong number of order 3
# 290 is an Armstrong number of order 3
# 291 is an Armstrong number of order 3
# 292 is an Armstrong number of order 3
# 293 is an Armstrong number of order 3
# 294 is an Armstrong number of order 3
# 295 is an Armstrong number of order 3
# 296 is an Armstrong number of order 3
# 297 is an Armstrong number of order 3
# 298 is an Armstrong number of order 3
# 299 is an Armstrong number of order 3
# 300 is an Armstrong number of order 3
# 301 is an Armstrong number of order 3
# 302 is an Armstrong number of order 3
# 303 is an Armstrong number of order 3
# 304 is an Armstrong number of order 3
# 305 is an Armstrong number of order 3
# 306 is an Armstrong number of order 3
# 307 is an Armstrong number of order 3
# 308 is an Armstrong number of order 3
# 309 is an Armstrong number of order 3
# 310 is an Armstrong number of order 3
# 311 is an Armstrong number of order 3
# 312 is an Armstrong number of order 3
# 313 is an Armstrong number of order 3
# 314 is an Armstrong number of order 3
# 315 is an Armstrong number of order 3
# 316 is an Armstrong number of order 3
# 317 is an Armstrong number of order 3
# 318 is an Armstrong number of order 3
# 319 is an Armstrong number of order 3
# 320 is an Armstrong number of order 3
# 321 is an Armstrong number of order 3
# 322 is an Armstrong number of order 3
# 323 is an Armstrong number of order 3
# 324 is an Armstrong number of order 3
# 325 is an Armstrong number of order 3
# 326 is an Armstrong number of order 3
# 327 is an Armstrong number of order 3
# 328 is an Armstrong number of order 3
# 329 is an Armstrong number of order 3
# 330 is an Armstrong number of order 3
# 331 is an Armstrong number of order 3
# 332 is an Armstrong number of order 3
# 333 is an Armstrong number of order 3
# 334 is an Armstrong number of order 3
# 335 is an Armstrong number of order 3
# 336 is an Armstrong number of order 3
# 337 is an Armstrong number of order 3
# 338 is an Armstrong number of order 3
# 339 is an Armstrong number of order 3
# 340 is an Armstrong number of order 3
# 341 is an Armstrong number of order 3
# 342 is an Armstrong number of order 3
# 343 is an Armstrong number of order 3
# 344 is an Armstrong number of order 3
# 345 is an Armstrong number of order 3
# 346 is an Armstrong number of order 3
# 347 is an Armstrong number of order 3
# 348 is an Armstrong number of order 3
# 349 is an Armstrong number of order 3
# 350 is an Armstrong number of order 3
# 351 is an Armstrong number of order 3
# 352 is an Armstrong number of order 3
# 353 is an Armstrong number of order 3
# 354 is an Armstrong number of order 3
# 355 is an Armstrong number of order 3
# 356 is an Armstrong number of order 3
# 357 is an Armstrong number of order 3
# 358 is an Armstrong number of order 3
# 359 is an Armstrong number of order 3
# 360 is an Armstrong number of order 3
# 361 is an Armstrong number of order 3
# 362 is an Armstrong number of order 3
# 363 is an Armstrong number of order 3
# 364 is an Armstrong number of order 3
# 365 is an Armstrong number of order 3
# 366 is an Armstrong number of order 3
# 367 is an Armstrong number of order 3
# 368 is an Armstrong number of order 3
# 369 is an Armstrong number of order 3
# 370 is an Armstrong number of order 3
# 371 is an Armstrong number of order 3
# 372 is an Armstrong number of order 3
# 373 is an Armstrong number of order 3
# 374 is an Armstrong number of order 3
# 375 is an Armstrong number of order 3
# 376 is an Armstrong number of order 3
# 377 is an Armstrong number of order 3
# 378 is an Armstrong number of order 3
# 379 is an Armstrong number of order 3
# 380 is an Armstrong number of order 3
# 381 is an Armstrong number of order 3
# 382 is an Armstrong number of order 3
# 383 is an Armstrong number of order 3
# 384 is an Armstrong number of order 3
# 385 is an Armstrong number of order 3
# 386 is an Armstrong number of order 3
# 387 is an Armstrong number of order 3
# 388 is an Armstrong number of order 3
# 389 is an Armstrong number of order 3
# 390 is an Armstrong number of order 3
# 391 is an Armstrong number of order 3
# 392 is an Armstrong number of order 3
# 393 is an Armstrong number of order 3
# 394 is an Armstrong number of order 3
# 395 is an Armstrong number of order 3
# 396 is an Armstrong number of order 3
# 397 is an Armstrong number of order 3
# 398 is an Armstrong number of order 3
# 399 is an Armstrong number of order 3
# 400 is an Armstrong number of order 3
# 401 is an Armstrong number of order 3
# 402 is an Armstrong number of order 3
# 403 is an Armstrong number of order 3
# 404 is an Armstrong number of order 3
# 405 is an Armstrong number of order 3
# 406 is an Armstrong number of order 3
# 407 is an Armstrong number of order 3
# 408 is an Armstrong number of order 3
# 409 is an Armstrong number of order 3
# 410 is an Armstrong number of order 3
# 411 is an Armstrong number of order 3
# 412 is an Armstrong number of order 3
# 413 is an Armstrong number of order 3
# 414 is an Armstrong number of order 3
# 415 is an Armstrong number of order 3
# 416 is an Armstrong number of order 3
# 417 is an Armstrong number of order 3
# 418 is an Armstrong number of order 3
# 419 is an Armstrong number of order 3
# 420 is an Armstrong number of order 3
# 421 is an Armstrong number of order 3
# 422 is an Armstrong number of order 3
# 423 is an Armstrong number of order 3
# 424 is an Armstrong number of order 3
# 425 is an Armstrong number of order 3
# 426 is an Armstrong number of order 3
# 427 is an Armstrong number of order 3
# 428 is an Armstrong number of order 3
# 429 is an Armstrong number of order 3
# 430 is an Armstrong number of order 3
# 431 is an Armstrong number of order 3
# 432 is an Armstrong number of order 3
# 433 is an Armstrong number of order 3
# 434 is an Armstrong number of order 3
# 435 is an Armstrong number of order 3
# 436 is an Armstrong number of order 3
# 437 is an Armstrong number of order 3
# 438 is an Armstrong number of order 3
# 439 is an Armstrong number of order 3
# 440 is an Armstrong number of order 3
# 441 is an Armstrong number of order 3
# 442 is an Armstrong number of order 3
# 443 is an Armstrong number of order 3
# 444 is an Armstrong number of order 3
# 445 is an Armstrong number of order 3
# 446 is an Armstrong number of order 3
# 447 is an Armstrong number of order 3
# 448 is an Armstrong number of order 3
# 449 is an Armstrong number of order 3
# 450 is an Armstrong number of order 3
# 451 is an Armstrong number of order 3
# 452 is an Armstrong number of order 3
# 453 is an Armstrong number of order 3
# 454 is an Armstrong number of order 3
# 455 is an Armstrong number of order 3
# 456 is an Armstrong number of order 3
# 457 is an Armstrong number of order 3
# 458 is an Armstrong number of order 3
# 459 is an Armstrong number of order 3
# 460 is an Armstrong number of order 3
# 461 is an Armstrong number of order 3
# 462 is an Armstrong number of order 3
# 463 is an Armstrong number of order 3
# 464 is an Armstrong number of order 3
# 465 is an Armstrong number of order 3
# 466 is an Armstrong number of order 3
# 467 is an Armstrong number of order 3
# 468 is an Armstrong number of order 3
# 469 is an Armstrong number of order 3
# 470 is an Armstrong number of order 3
# 471 is an Armstrong number of order 3
# 472 is an Armstrong number of order 3
# 473 is an Armstrong number of order 3
# 474 is an Armstrong number of order 3
# 475 is an Armstrong number of order 3
# 476 is an Armstrong number of order 3
# 477 is an Armstrong number of order 3
# 478 is an Armstrong number of order 3
# 479 is an Armstrong number of order 3
# 480 is an Armstrong number of order 3
# 481 is an Armstrong number of order 3
# 482 is an Armstrong number of order 3
# 483 is an Armstrong number of order 3
# 484 is an Armstrong number of order 3
# 485 is an Armstrong number of order 3
# 486 is an Armstrong number of order 3
# 487 is an Armstrong number of order 3
# 488 is an Armstrong number of order 3
# 489 is an Armstrong number of order 3
# 490 is an Armstrong number of order 3
# 491 is an Armstrong number of order 3
# 492 is an Armstrong number of order 3
# 493 is an Armstrong number of order 3
# 494 is an Armstrong number of order 3
# 495 is an Armstrong number of order 3
# 496 is an Armstrong number of order 3
# 497 is an Armstrong number of order 3
# 498 is an Armstrong number of order 3
# 499 is an Armstrong number of order 3
# 500 is an Armstrong number of order 3
# 501 is an Armstrong number of order 3
# 502 is an Armstrong number of order 3
# 503 is an Armstrong number of order 3
# 504 is an Armstrong number of order 3
# 505 is an Armstrong number of order 3
# 506 is an Armstrong number of order 3
# 507 is an Armstrong number of order 3
# 508 is an Armstrong number of order 3
# 509 is an Armstrong number of order 3
# 510 is an Armstrong number of order 3
# 511 is an Armstrong number of order 3
# 512 is an Armstrong number of order 3
# 513 is an Armstrong number of order 3
# 514 is an Armstrong number of order 3
# 515 is an Armstrong number of order 3
# 516 is an Armstrong number of order 3
# 517 is an Armstrong number of order 3
# 518 is an Armstrong number of order 3
# 519 is an Armstrong number of order 3
# 520 is an Armstrong number of order 3
# 521 is an Armstrong number of order 3
# 522 is an Armstrong number of order 3
# 523 is an Armstrong number of order 3
# 524 is an Armstrong number of order 3
# 525 is an Armstrong number of order 3
# 526 is an Armstrong number of order 3
# 527 is an Armstrong number of order 3
# 528 is an Armstrong number of order 3
# 529 is an Armstrong number of order 3
# 530 is an Armstrong number of order 3
# 531 is an Armstrong number of order 3
# 532 is an Armstrong number of order 3
# 533 is an Armstrong number of order 3
# 534 is an Armstrong number of order 3
# 535 is an Armstrong number of order 3
# 536 is an Armstrong number of order 3
# 537 is an Armstrong number of order 3
# 538 is an Armstrong number of order 3
# 539 is an Armstrong number of order 3
# 540 is an Armstrong number of order 3
# 541 is an Armstrong number of order 3
# 542 is an Armstrong number of order 3
# 543 is an Armstrong number of order 3
# 544 is an Armstrong number of order 3
# 545 is an Armstrong number of order 3
# 546 is an Armstrong number of order 3
# 547 is an Armstrong number of order 3
# 548 is an Armstrong number of order 3
# 549 is an Armstrong number of order 3
# 550 is an Armstrong number of order 3
# 551 is an Armstrong number of order 3
# 552 is an Armstrong number of order 3
# 553 is an Armstrong number of order 3
# 554 is an Armstrong number of order 3
# 555 is an Armstrong number of order 3
# 556 is an Armstrong number of order 3
# 557 is an Armstrong number of order 3
# 558 is an Armstrong number of order 3
# 559 is an Armstrong number of order 3
# 560 is an Armstrong number of order 3
# 561 is an Armstrong number of order 3
# 562 is an Armstrong number of order 3
# 563 is an Armstrong number of order 3
# 564 is an Armstrong number of order 3
# 565 is an Armstrong number of order 3
# 566 is an Armstrong number of order 3
# 567 is an Armstrong number of order 3
# 568 is an Armstrong number of order 3
# 569 is an Armstrong number of order 3
# 570 is an Armstrong number of order 3
# 571 is an Armstrong number of order 3
# 572 is an Armstrong number of order 3
# 573 is an Armstrong number of order 3
# 574 is an Armstrong number of order 3
# 575 is an Armstrong number of order 3
# 576 is an Armstrong number of order 3
# 577 is an Armstrong number of order 3
# 578 is an Armstrong number of order 3
# 579 is an Armstrong number of order 3
# 580 is an Armstrong number of order 3
# 581 is an Armstrong number of order 3
# 582 is an Armstrong number of order 3
# 583 is an Armstrong number of order 3
# 584 is an Armstrong number of order 3
# 585 is an Armstrong number of order 3
# 586 is an Armstrong number of order 3
# 587 is an Armstrong number of order 3
# 588 is an Armstrong number of order 3
# 589 is an Armstrong number of order 3
# 590 is an Armstrong number of order 3
# 591 is an Armstrong number of order 3
# 592 is an Armstrong number of order 3
# 593 is an Armstrong number of order 3
# 594 is an Armstrong number of order 3
# 595 is an Armstrong number of order 3
# 596 is an Armstrong number of order 3
# 597 is an Armstrong number of order 3
# 598 is an Armstrong number of order 3
# 599 is an Armstrong number of order 3
# 600 is an Armstrong number of order 3
# 601 is an Armstrong number of order 3
# 602 is an Armstrong number of order 3
# 603 is an Armstrong number of order 3
# 604 is an Armstrong number of order 3
# 605 is an Armstrong number of order 3
# 606 is an Armstrong number of order 3
# 607 is an Armstrong number of order 3
# 608 is an Armstrong number of order 3
# 609 is an Armstrong number of order 3
# 610 is an Armstrong number of order 3
# 611 is an Armstrong number of order 3
# 612 is an Armstrong number of order 3
# 613 is an Armstrong number of order 3
# 614 is an Armstrong number of order 3
# 615 is an Armstrong number of order 3
# 616 is an Armstrong number of order 3
# 617 is an Armstrong number of order 3
# 618 is an Armstrong number of order 3
# 619 is an Armstrong number of order 3
# 620 is an Armstrong number of order 3
# 621 is an Armstrong number of order 3
# 622 is an Armstrong number of order 3
# 623 is an Armstrong number of order 3
# 624 is an Armstrong number of order 3
# 625 is an Armstrong number of order 3
# 626 is an Armstrong number of order 3
# 627 is an Armstrong number of order 3
# 628 is an Armstrong number of order 3
# 629 is an Armstrong number of order 3
# 630 is an Armstrong number of order 3
# 631 is an Armstrong number of order 3
# 632 is an Armstrong number of order 3
# 633 is an Armstrong number of order 3
# 634 is an Armstrong number of order 3
# 635 is an Armstrong number of order 3
# 636 is an Armstrong number of order 3
# 637 is an Armstrong number of order 3
# 638 is an Armstrong number of order 3
# 639 is an Armstrong number of order 3
# 640 is an Armstrong number of order 3
# 641 is an Armstrong number of order 3
# 642 is an Armstrong number of order 3
# 643 is an Armstrong number of order 3
# 644 is an Armstrong number of order 3
# 645 is an Armstrong number of order 3
# 646 is an Armstrong number of order 3
# 647 is an Armstrong number of order 3
# 648 is an Armstrong number of order 3
# 649 is an Armstrong number of order 3
# 650 is an Armstrong number of order 3
# 651 is an Armstrong number of order 3
# 652 is an Armstrong number of order 3
# 653 is an Armstrong number of order 3
# 654 is an Armstrong number of order 3
# 655 is an Armstrong number of order 3
# 656 is an Armstrong number of order 3
# 657 is an Armstrong number of order 3
# 658 is an Armstrong number of order 3
# 659 is an Armstrong number of order 3
# 660 is an Armstrong number of order 3
# 661 is an Armstrong number of order 3
# 662 is an Armstrong number of order 3
# 663 is an Armstrong number of order 3
# 664 is an Armstrong number of order 3
# 665 is an Armstrong number of order 3
# 666 is an Armstrong number of order 3
# 667 is an Armstrong number of order 3
# 668 is an Armstrong number of order 3
# 669 is an Armstrong number of order 3
# 670 is an Armstrong number of order 3
# 671 is an Armstrong number of order 3
# 672 is an Armstrong number of order 3
# 673 is an Armstrong number of order 3
# 674 is an Armstrong number of order 3
# 675 is an Armstrong number of order 3
# 676 is an Armstrong number of order 3
# 677 is an Armstrong number of order 3
# 678 is an Armstrong number of order 3
# 679 is an Armstrong number of order 3
# 680 is an Armstrong number of order 3
# 681 is an Armstrong number of order 3
# 682 is an Armstrong number of order 3
# 683 is an Armstrong number of order 3
# 684 is an Armstrong number of order 3
# 685 is an Armstrong number of order 3
# 686 is an Armstrong number of order 3
# 687 is an Armstrong number of order 3
# 688 is an Armstrong number of order 3
# 689 is an Armstrong number of order 3
# 690 is an Armstrong number of order 3
# 691 is an Armstrong number of order 3
# 692 is an Armstrong number of order 3
# 693 is an Armstrong number of order 3
# 694 is an Armstrong number of order 3
# 695 is an Armstrong number of order 3
# 696 is an Armstrong number of order 3
# 697 is an Armstrong number of order 3
# 698 is an Armstrong number of order 3
# 699 is an Armstrong number of order 3
# 700 is an Armstrong number of order 3
# 701 is an Armstrong number of order 3
# 702 is an Armstrong number of order 3
# 703 is an Armstrong number of order 3
# 704 is an Armstrong number of order 3
# 705 is an Armstrong number of order 3
# 706 is an Armstrong number of order 3
# 707 is an Armstrong number of order 3
# 708 is an Armstrong number of order 3
# 709 is an Armstrong number of order 3
# 710 is an Armstrong number of order 3
# 711 is an Armstrong number of order 3
# 712 is an Armstrong number of order 3
# 713 is an Armstrong number of order 3
# 714 is an Armstrong number of order 3
# 715 is an Armstrong number of order 3
# 716 is an Armstrong number of order 3
# 717 is an Armstrong number of order 3
# 718 is an Armstrong number of order 3
# 719 is an Armstrong number of order 3
# 720 is an Armstrong number of order 3
# 721 is an Armstrong number of order 3
# 722 is an Armstrong number of order 3
# 723 is an Armstrong number of order 3
# 724 is an Armstrong number of order 3
# 725 is an Armstrong number of order 3
# 726 is an Armstrong number of order 3
# 727 is an Armstrong number of order 3
# 728 is an Armstrong number of order 3
# 729 is an Armstrong number of order 3
# 730 is an Armstrong number of order 3
# 731 is an Armstrong number of order 3
# 732 is an Armstrong number of order 3
# 733 is an Armstrong number of order 3
# 734 is an Armstrong number of order 3
# 735 is an Armstrong number of order 3
# 736 is an Armstrong number of order 3
# 737 is an Armstrong number of order 3
# 738 is an Armstrong number of order 3
# 739 is an Armstrong number of order 3
# 740 is an Armstrong number of order 3
# 741 is an Armstrong number of order 3
# 742 is an Armstrong number of order 3
# 743 is an Armstrong number of order 3
# 744 is an Armstrong number of order 3
# 745 is an Armstrong number of order 3
# 746 is an Armstrong number of order 3
# 747 is an Armstrong number of order 3
# 748 is an Armstrong number of order 3
# 749 is an Armstrong number of order 3
# 750 is an Armstrong number of order 3
# 751 is an Armstrong number of order 3
# 752 is an Armstrong number of order 3
# 753 is an Armstrong number of order 3
# 754 is an Armstrong number of order 3
# 755 is an Armstrong number of order 3
# 756 is an Armstrong number of order 3
# 757 is an Armstrong number of order 3
# 758 is an Armstrong number of order 3
# 759 is an Armstrong number of order 3
# 760 is an Armstrong number of order 3
# 761 is an Armstrong number of order 3
# 762 is an Armstrong number of order 3
# 763 is an Armstrong number of order 3
# 764 is an Armstrong number of order 3
# 765 is an Armstrong number of order 3
# 766 is an Armstrong number of order 3
# 767 is an Armstrong number of order 3
# 768 is an Armstrong number of order 3
# 769 is an Armstrong number of order 3
# 770 is an Armstrong number of order 3
# 771 is an Armstrong number of order 3
# 772 is an Armstrong number of order 3
# 773 is an Armstrong number of order 3
# 774 is an Armstrong number of order 3
# 775 is an Armstrong number of order 3
# 776 is an Armstrong number of order 3
# 777 is an Armstrong number of order 3
# 778 is an Armstrong number of order 3
# 779 is an Armstrong number of order 3
# 780 is an Armstrong number of order 3
# 781 is an Armstrong number of order 3
# 782 is an Armstrong number of order 3
# 783 is an Armstrong number of order 3
# 784 is an Armstrong number of order 3
# 785 is an Armstrong number of order 3
# 786 is an Armstrong number of order 3
# 787 is an Armstrong number of order 3
# 788 is an Armstrong number of order 3
# 789 is an Armstrong number of order 3
# 790 is an Armstrong number of order 3
# 791 is an Armstrong number of order 3
# 792 is an Armstrong number of order 3
# 793 is an Armstrong number of order 3
# 794 is an Armstrong number of order 3
# 795 is an Armstrong number of order 3
# 796 is an Armstrong number of order 3
# 797 is an Armstrong number of order 3
# 798 is an Armstrong number of order 3
# 799 is an Armstrong number of order 3
# 800 is an Armstrong number of order 3
# 801 is an Armstrong number of order 3
# 802 is an Armstrong number of order 3
# 803 is an Armstrong number of order 3
# 804 is an Armstrong number of order 3
# 805 is an Armstrong number of order 3
# 806 is an Armstrong number of order 3
# 807 is an Armstrong number of order 3
# 808 is an Armstrong number of order 3
# 809 is an Armstrong number of order 3
# 810 is an Armstrong number of order 3
# 811 is an Armstrong number of order 3
# 812 is an Armstrong number of order 3
# 813 is an Armstrong number of order 3
# 814 is an Armstrong number of order 3
# 815 is an Armstrong number of order 3
# 816 is an Armstrong number of order 3
# 817 is an Armstrong number of order 3
# 818 is an Armstrong number of order 3
# 819 is an Armstrong number of order 3
# 820 is an Armstrong number of order 3
# 821 is an Armstrong number of order 3
# 822 is an Armstrong number of order 3
# 823 is an Armstrong number of order 3
# 824 is an Armstrong number of order 3
# 825 is an Armstrong number of order 3
# 826 is an Armstrong number of order 3
# 827 is an Armstrong number of order 3
# 828 is an Armstrong number of order 3
# 829 is an Armstrong number of order 3
# 830 is an Armstrong number of order 3
# 831 is an Armstrong number of order 3
# 832 is an Armstrong number of order 3
# 833 is an Armstrong number of order 3
# 834 is an Armstrong number of order 3
# 835 is an Armstrong number of order 3
# 836 is an Armstrong number of order 3
# 837 is an Armstrong number of order 3
# 838 is an Armstrong number of order 3
# 839 is an Armstrong number of order 3
# 840 is an Armstrong number of order 3
# 841 is an Armstrong number of order 3
# 842 is an Armstrong number of order 3
# 843 is an Armstrong number of order 3
# 844 is an Armstrong number of order 3
# 845 is an Armstrong number of order 3
# 846 is an Armstrong number of order 3
# 847 is an Armstrong number of order 3
# 848 is an Armstrong number of order 3
# 849 is an Armstrong number of order 3
# 850 is an Armstrong number of order 3
# 851 is an Armstrong number of order 3
# 852 is an Armstrong number of order 3
# 853 is an Armstrong number of order 3
# 854 is an Armstrong number of order 3
# 855 is an Armstrong number of order 3
# 856 is an Armstrong number of order 3
# 857 is an Armstrong number of order 3
# 858 is an Armstrong number of order 3
# 859 is an Armstrong number of order 3
# 860 is an Armstrong number of order 3
# 861 is an Armstrong number of order 3
# 862 is an Armstrong number of order 3
# 863 is an Armstrong number of order 3
# 864 is an Armstrong number of order 3
# 865 is an Armstrong number of order 3
# 866 is an Armstrong number of order 3
# 867 is an Armstrong number of order 3
# 868 is an Armstrong number of order 3
# 869 is an Armstrong number of order 3
# 870 is an Armstrong number of order 3
# 871 is an Armstrong number of order 3
# 872 is an Armstrong number of order 3
# 873 is an Armstrong number of order 3
# 874 is an Armstrong number of order 3
# 875 is an Armstrong number of order 3
# 876 is an Armstrong number of order 3
# 877 is an Armstrong number of order 3
# 878 is an Armstrong number of order 3
# 879 is an Armstrong number of order 3
# 880 is an Armstrong number of order 3
# 881 is an Armstrong number of order 3
# 882 is an Armstrong number of order 3
# 883 is an Armstrong number of order 3
# 884 is an Armstrong number of order 3
# 885 is an Armstrong number of order 3
# 886 is an Armstrong number of order 3
# 887 is an Armstrong number of order 3
# 888 is an Armstrong number of order 3
# 889 is an Armstrong number of order 3
# 890 is an Armstrong number of order 3
# 891 is an Armstrong number of order 3
# 892 is an Armstrong number of order 3
# 893 is an Armstrong number of order 3
# 894 is an Armstrong number of order 3
# 895 is an Armstrong number of order 3
# 896 is an Armstrong number of order 3
# 897 is an Armstrong number of order 3
# 898 is an Armstrong number of order 3
# 899 is an Armstrong number of order 3
# 900 is an Armstrong number of order 3
# 901 is an Armstrong number of order 3
# 902 is an Armstrong number of order 3
# 903 is an Armstrong number of order 3
# 904 is an Armstrong number of order 3
# 905 is an Armstrong number of order 3
# 906 is an Armstrong number of order 3
# 907 is an Armstrong number of order 3
# 908 is an Armstrong number of order 3
# 909 is an Armstrong number of order 3
# 910 is an Armstrong number of order 3
# 911 is an Armstrong number of order 3
# 912 is an Armstrong number of order 3
# 913 is an Armstrong number of order 3
# 914 is an Armstrong number of order 3
# 915 is an Armstrong number of order 3
# 916 is an Armstrong number of order 3
# 917 is an Armstrong number of order 3
# 918 is an Armstrong number of order 3
# 919 is an Armstrong number of order 3
# 920 is an Armstrong number of order 3
# 921 is an Armstrong number of order 3
# 922 is an Armstrong number of order 3
# 923 is an Armstrong number of order 3
# 924 is an Armstrong number of order 3
# 925 is an Armstrong number of order 3
# 926 is an Armstrong number of order 3
# 927 is an Armstrong number of order 3
# 928 is an Armstrong number of order 3
# 929 is an Armstrong number of order 3
# 930 is an Armstrong number of order 3
# 931 is an Armstrong number of order 3
# 932 is an Armstrong number of order 3
# 933 is an Armstrong number of order 3
# 934 is an Armstrong number of order 3
# 935 is an Armstrong number of order 3
# 936 is an Armstrong number of order 3
# 937 is an Armstrong number of order 3
# 938 is an Armstrong number of order 3
# 939 is an Armstrong number of order 3
# 940 is an Armstrong number of order 3
# 941 is an Armstrong number of order 3
# 942 is an Armstrong number of order 3
# 943 is an Armstrong number of order 3
# 944 is an Armstrong number of order 3
# 945 is an Armstrong number of order 3
# 946 is an Armstrong number of order 3
# 947 is an Armstrong number of order 3
# 948 is an Armstrong number of order 3
# 949 is an Armstrong number of order 3
# 950 is an Armstrong number of order 3
# 951 is an Armstrong number of order 3
# 952 is an Armstrong number of order 3
# 953 is an Armstrong number of order 3
# 954 is an Armstrong number of order 3
# 955 is an Armstrong number of order 3
# 956 is an Armstrong number of order 3
# 957 is an Armstrong number of order 3
# 958 is an Armstrong number of order 3
# 959 is an Armstrong number of order 3
# 960 is an Armstrong number of order 3
# 961 is an Armstrong number of order 3
# 962 is an Armstrong number of order 3
# 963 is an Armstrong number of order 3
# 964 is an Armstrong number of order 3
# 965 is an Armstrong number of order 3
# 966 is an Armstrong number of order 3
# 967 is an Armstrong number of order 3
# 968 is an Armstrong number of order 3
# 969 is an Armstrong number of order 3
# 970 is an Armstrong number of order 3
# 971 is an Armstrong number of order 3
# 972 is an Armstrong number of order 3
# 973 is an Armstrong number of order 3
# 974 is an Armstrong number of order 3
# 975 is an Armstrong number of order 3
# 976 is an Armstrong number of order 3
# 977 is an Armstrong number of order 3
# 978 is an Armstrong number of order 3
# 979 is an Armstrong number of order 3
# 980 is an Armstrong number of order 3
# 981 is an Armstrong number of order 3
# 982 is an Armstrong number of order 3
# 983 is an Armstrong number of order 3
# 984 is an Armstrong number of order 3
# 985 is an Armstrong number of order 3
# 986 is an Armstrong number of order 3
# 987 is an Armstrong number of order 3
# 988 is an Armstrong number of order 3
# 989 is an Armstrong number of order 3
# 990 is an Armstrong number of order 3
# 991 is an Armstrong number of order 3
# 992 is an Armstrong number of order 3
# 993 is an Armstrong number of order 3
# 994 is an Armstrong number of order 3
# 995 is an Armstrong number of order 3
# 996 is an Armstrong number of order 3
# 997 is an Armstrong number of order 3
# 998 is an Armstrong number of order 3
# 999 is an Armstrong number of order 3
# 1000 is an Armstrong number of order 4
